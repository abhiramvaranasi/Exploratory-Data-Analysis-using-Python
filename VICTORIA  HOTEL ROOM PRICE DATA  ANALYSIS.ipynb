# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import io
# %cd "D:\PYTHON DATA SETS"
# Out:
# D:\PYTHON DATA SETS

# %%
victoria=pd.read_csv("victoria.csv")

# %%
victoria.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7031 entries, 0 to 7030
# Data columns (total 18 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              7031 non-null   int64
#  1   name                            7031 non-null   object
#  2   host_id                         7031 non-null   int64
#  3   host_name                       7031 non-null   object
#  4   neighbourhood_group             0 non-null      float64
#  5   neighbourhood                   7031 non-null   object
#  6   latitude                        7031 non-null   float64
#  7   longitude                       7031 non-null   float64
#  8   room_type                       7031 non-null   object
#  9   price                           7031 non-null   int64
#  10  minimum_nights                  7031 non-null   int64
#  11  number_of_reviews               7031 non-null   int64
#  12  last_review                     6159 non-null   object
#  13  reviews_per_month               6159 non-null   float64
#  14  calculated_host_listings_count  7031 non-null   int64
#  15  availability_365                7031 non-null   int64
#  16  number_of_reviews_ltm           7031 non-null   int64
#  17  license                         0 non-null      float64
# dtypes: float64(5), int64(8), object(5)
# memory usage: 988.9+ KB

# %%
victoria['price'].head()
# Out:
# 0    500
# 1     68
# 2    200
# 3    390
# 4    160
# Name: price, dtype: int64

# %%
victoria.price.head(4)
# Out:
# 0    500
# 1     68
# 2    200
# 3    390
# Name: price, dtype: int64

# %%
victoria[['price','neighbourhood','room_type']].head()
# Out:
#    price       neighbourhood        room_type
# 0    500          Surf Coast  Entire home/apt
# 1     68               Moyne     Private room
# 2    200               Moyne     Private room
# 3    390     Greater Geelong  Entire home/apt
# 4    160  Southern Grampians     Private room

# %%
victoria.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365', 'number_of_reviews_ltm', 'license'],
#       dtype='object')

# %%
victoria.iloc[:,5].head()
# Out:
# 0            Surf Coast
# 1                 Moyne
# 2                 Moyne
# 3       Greater Geelong
# 4    Southern Grampians
# Name: neighbourhood, dtype: object

# %%
victoria.iloc[:,[1,2,8,9,10,11]].head()
# Out:
#                                 name   host_id        room_type  price  \
# 0     the OCEAN HAVEN - pet-friendly     81292  Entire home/apt    500
# 1       Cosy self-contained bungalow  11030818     Private room     68
# 2  The Cottage at Calgary  Killarney  11025062     Private room    200
# 3                BYRON@Portarlington  11272538  Entire home/apt    390
# 4            Garland Cottage B and B  11273845     Private room    160
#
#    minimum_nights  number_of_reviews
# 0               5                 51
# 1               2                417
# 2               2                  8
# 3               2                 17
# 4               2                 97

# %%
victoria.iloc[[2,5,8,4,3]]
# Out:
#         id                                             name   host_id  \
# 2  2198761                The Cottage at Calgary  Killarney  11025062
# 5  2224983  Entire Seacroft Historic Ocean Front Guesthouse  10814850
# 8  4244978                  Beachcomber Retreat - Free WiFi  22029747
# 4  2210140                          Garland Cottage B and B  11273845
# 3  2209882                              BYRON@Portarlington  11272538
#
#   host_name  neighbourhood_group       neighbourhood  latitude  longitude  \
# 2   Heather                  NaN               Moyne -38.34533  142.32739
# 5       Sam                  NaN         Colac Otway -38.69511  143.80196
# 8     Merri                  NaN         Colac Otway -38.74733  143.66325
# 4     Rosie                  NaN  Southern Grampians -37.74830  142.02087
# 3   Belinda                  NaN     Greater Geelong -38.12057  144.68958
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# 2     Private room    200               2                  8  2022-03-14
# 5     Private room   2499               2                140  2021-04-23
# 8  Entire home/apt    115               1                498  2023-01-07
# 4     Private room    160               2                 97  2023-01-07
# 3  Entire home/apt    390               2                 17  2022-02-05
#
#    reviews_per_month  calculated_host_listings_count  availability_365  \
# 2               0.08                               3               287
# 5               1.26                              26               240
# 8               4.88                               1                 0
# 4               0.89                               1               258
# 3               0.15                               1                 1
#
#    number_of_reviews_ltm  license
# 2                      0      NaN
# 5                      0      NaN
# 8                     15      NaN
# 4                      9      NaN
# 3                      0      NaN

# %%
victoria.price.describe()
# Out:
# count     7031.000000
# mean       382.259565
# std        523.971871
# min         20.000000
# 25%        207.000000
# 50%        303.000000
# 75%        457.000000
# max      36408.000000
# Name: price, dtype: float64

# %%
victoria.iloc[:,11].describe()
# Out:
# count    7031.000000
# mean       44.433793
# std        83.289962
# min         0.000000
# 25%         3.000000
# 50%        13.000000
# 75%        49.000000
# max      1018.000000
# Name: number_of_reviews, dtype: float64

# %%
print(victoria.price.skew())
print(victoria.price.kurt())
# Out:
# 47.846763648922995
# 3202.6182798986542

# %%
print("skewness is: ",victoria.price.skew())
print("kurtosis is: ",victoria.price.kurt())
# Out:
# skewness is:  47.846763648922995
# kurtosis is:  3202.6182798986542

# %%
victoria.price.plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
victoria.price.plot(kind='box',vert=False)
# Out:
# <Axes: >

# %%
victoria.price.plot(kind='density',color='red')
# Out:
# <Axes: ylabel='Density'>

# %%
victoria.room_type.value_counts()
# Out:
# Entire home/apt    6357
# Private room        646
# Hotel room           25
# Shared room           3
# Name: room_type, dtype: int64

# %%
victoria.room_type.value_counts().plot(kind='pie',autopct='%.2f%%')
# Out:
# <Axes: ylabel='room_type'>

# %%
victoria.room_type.value_counts().plot(kind='bar',color='green')
# Out:
# <Axes: >

# %%
ax=victoria.room_type.value_counts().plot(kind='bar',color='green')
for i in ax.containers:
    ax.bar_label(i,color='blue')

# %%
victoria.neighbourhood.value_counts()
# Out:
# Surf Coast            2246
# Greater Geelong       2141
# Colac Otway           1002
# Moyne                  499
# Warrnambool            357
# Corangamite            262
# Queenscliffe           229
# Glenelg                181
# Southern Grampians     114
# Name: neighbourhood, dtype: int64

# %%
pd.set_option("display.max_rows",8)
victoria.neighbourhood.value_counts()
# Out:
# Surf Coast            2246
# Greater Geelong       2141
# Colac Otway           1002
# Moyne                  499
#                       ...
# Corangamite            262
# Queenscliffe           229
# Glenelg                181
# Southern Grampians     114
# Name: neighbourhood, Length: 9, dtype: int64

# %%
victoria.neighbourhood.value_counts().nlargest(5)
# Out:
# Surf Coast         2246
# Greater Geelong    2141
# Colac Otway        1002
# Moyne               499
# Warrnambool         357
# Name: neighbourhood, dtype: int64

# %%
plt.figure(figsize=(15,7))
ax=victoria.neighbourhood.value_counts().nlargest(5).plot(kind='bar',color='purple')
for i in ax.containers:
    ax.bar_label(i,fontsize=15)

# %%
victoria.number_of_reviews.groupby(
victoria.neighbourhood).sum().sort_values(
    ascending=False).nlargest(5)
# Out:
# neighbourhood
# Greater Geelong    77938
# Surf Coast         75052
# Colac Otway        70508
# Warrnambool        25354
# Moyne              24174
# Name: number_of_reviews, dtype: int64

# %%
ax=victoria.number_of_reviews.groupby(
victoria.neighbourhood).sum().sort_values(
ascending=False).nlargest(5).plot(kind='bar')
for i in ax.containers:
    ax.bar_label(i)

# %%
victoria.price.groupby(
victoria.neighbourhood).mean().sort_values(
ascending=False).nlargest(5)
# Out:
# neighbourhood
# Surf Coast         460.847284
# Queenscliffe       446.240175
# Moyne              377.963928
# Colac Otway        371.467066
# Greater Geelong    356.834657
# Name: price, dtype: float64

# %%
plt.figure(figsize=(15,7))
ax=victoria.price.groupby(
victoria.neighbourhood).mean().sort_values(
ascending=False).nlargest(6).plot(kind='bar',color='orange')
for i in ax.containers:
    ax.bar_label(i)

# %%
plt.figure(figsize=(15,7))
ax=victoria.price.groupby(
victoria.neighbourhood).mean().sort_values(
ascending=False).nsmallest(6).plot(kind='bar',color='orange')
for i in ax.containers:
    ax.bar_label(i)
